# %% [markdown]
# <a href="https://colab.research.google.com/github/Deadman621/banknote-authentication/blob/main/notebooks/06_denomination_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Deadman621/banknote-authentication.git
# Out:
# Cloning into 'banknote-authentication'...
# remote: Enumerating objects: 651, done.
# remote: Counting objects: 100% (651/651), done.
# remote: Compressing objects: 100% (375/375), done.
# remote: Total 651 (delta 363), reused 523 (delta 259), pack-reused 0 (from 0)
# Receiving objects: 100% (651/651), 2.16 MiB | 27.02 MiB/s, done.
# Resolving deltas: 100% (363/363), done.

# %%
# %cd banknote-authentication
# Out:
# /content/banknote-authentication

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rahnumatasnim1604103/bangladeshi-banknote-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 4.19G/4.19G [00:32<00:00, 140MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/rahnumatasnim1604103/bangladeshi-banknote-dataset/versions/1

# %%
import os
import shutil

src = "/root/.cache/kagglehub/datasets/rahnumatasnim1604103/bangladeshi-banknote-dataset/versions/1/"
dst = "/content/banknote-authentication/data/raw/denomination/archive/"

os.makedirs(os.path.dirname(dst), exist_ok=True)

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.move(src, dst)

print(f"Dataset moved to: {dst}")
# Out:
# Dataset moved to: /content/banknote-authentication/data/raw/denomination/archive/

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/banknote-authentication/experiments
# !rm -rf /content/banknote-authentication/experiments
# !ln -s /content/drive/MyDrive/banknote-authentication/experiments /content/banknote-authentication/experiments
# Out:
# Mounted at /content/drive

# %%
module = "denomination"
model = "swin_transformer" # add model here
experiment_name = "train_1"
checkpoint_path = "/content/drive/MyDrive/banknote-authentication/experiments/denomination/swin_transformer/train_1/20260721_065629/checkpoints/last.pt" # Change this to your path

# !python -m scripts.train \
    --module {module} \
    --model {model} \
    --experiment-name {experiment_name}
# Out:
# Train samples: 56431
# Validation samples: 14111
# Overlap: 0
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Class names: ('2', '5', '10', '20', '50', '100', '500', '1000')
# Class weights: tensor([1.7273, 1.3801, 1.0520, 0.6215, 0.8964, 1.2599, 0.7393, 1.1429])
# [2026-07-21 07:11:21] INFO - Starting training for module=denomination model=swin_transformer on cuda
# [2026-07-21 07:11:21] INFO - Training started.
# ...
